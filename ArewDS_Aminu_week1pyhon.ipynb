# %% [markdown]
# # Arewa Data Science Introduction to Python
# ## Week 1: Self-Paced Python Practice Lab
#
# ---
#
# ### Welcome!
#
# This notebook contains examples and exercises based on what we covered in our first class. Work through each section at your own pace, running the code cells and completing the exercises.
#
# ### Quick Reminders:
#
# - **To run a code cell**: Click on it and press `Shift + Enter` (or click the Play ▶️ button)
# - **Run cells in order**: Start from the top and work your way down
# - **Experiment**: Feel free to modify the code and see what happens!
# - **Errors are okay**: They help you learn. Read the error messages carefully!
#
# ---

# %%
# Printing calculations
print(10 + 5)

# %%
#Printing numbers
print(42)
# Out:
# 42

# %%
### Example 1.1: Basic Print Statements
# Printing a simple message
print("Hi there")
# Out:
# Hi there

# %%
name = " ken Lambert "
print (name)
# Out:
#  ken Lambert

# %%
print (" the number is ", 40, 5, "and", 29)
# Out:
#  the number is  40 5 and 29

# %%
name = " ken lambert "
age = 40
print ("my name is ken lamber", "and age is", 40)
print (name)
print ( age)
# Out:
# my name is ken lamber and age is 40
#  ken lambert
# 40

# %%
age = 25
heiht = 5.9
print (age)
print ( heiht)
print ("age", heiht)
# Out:
# 25
# 5.9

# %%
Lenth = 4
Width = 4
Area = Lenth + Width
print ( "The  Area  is", Area )

# %%
best_city = "Kano"
many_local_gov = 44
print ( "best city", many_local_gov )
# Out:
# best city 44

# %%
low_temp = 36
High_temp = 70
print ( " The High temp is", High_temp, "and low_temp is", low_temp )
# Out:
#  The High temp is 70 and low_temp is 36

# %%
num1 = 4
num2 = 6
num3 = 7
print (" the num1", "is num1", "and num2", "is num2", "and num3", "is num3", num4 )
# Out:
#  the num1 is num1 and num2 is num2 and num3 is num3 6

# %%
lenth = 4
width = 66
sum = lenth+width
print(sum)
# Out:
# 70

# %%
name = input (" enter your name ")
print = ( " hello ", name )

# %%
favourite_colour = input (" what is your favourite colour ")
favourite_food = input (" what your favourite food ")
print (" your favourite_colour" "is favourite_colour")
print (" your favourite_food ")

# %%
name = input (" what is your name ")
print ( name )
last_name = (" muhammad ")
print ( last_name)
# Out:
# aminu
#  muhammad

# %%
# calculating area
lenth = int (input("enter the lenth of rectangle:"))
width = int(input( "enter the width of the rectangle:"))
area = (lenth + width)
print ( "the area is ", area )
# Out:
# the area is  42

# %%
# why conversion
num1 = int(input ("enter first number:"))
num2 = int(input (" enterth second number:"))
result = num1 + num2 
print ("the result is", result)
# adding two numbers
first = int(input(" enter the first numer:"))
second = float(input(" entr the second number:"))
sum = first + second
print ("the sum is", first+second)
# Out:
# the result is 8
# the sum is 12.0

# %%
price = int(input("enter the price"))
tax_rate = 0.9
total = float(price+(price * tax_rate))
print ( " toatal with tax", total)
# Out:
#  toatal with tax 5.7

# %%
temp_celcius = float(input (" enter temp in celcius"))
farenhigh = ( temp_celcius+9/5+32)
print (" the temp in farenhigh", farenhigh)
# Out:
#  the temp in farenhigh 73.8

# %%
# simple calculator
x = int (input (" enter the first number"))
y = int (input (" enter the second number"))
sum = int(x+y)
Quient = (x/y)
Product = (x*y)
Difference = float(x-y)
print (" the sum is", sum)
print (" the quient is" ,  Quient)
print (" the product of x and y is", Product)
print (" the difference of x and y is ", Difference )
# Out:
#  the sum is 6
#  the quient is 2.0
#  the product of x and y is 8
#  the difference of x and y is  2.0

# %%
# asignment
# the tex has to be converted to either int or float ( numerical)
# 
lenth = float (input (" enter the lenth of rectangle:"))
width = float (input (" enter the width of the rectangle:"))
area = lenth*width
perimeter = float((2*lenth + 2*width))
print (" the area is", area)
print (" the perimeter is ", perimeter)
# Out:
#  the area is 4.0
#  the perimeter is  8.0

# %%
# challang 2, shopping bil calculator
first_item = int(input(" enter the price of peak "))
second_item = int(input (" enter the price of milo "))
third_item = int(input (" enter the price of sugar "))
sub_total = (first_item + second_item + third_item)
percentage_of_sub_total = int(((6/100)*(sub_total)))
final_total = sub_total + percentage_of_sub_total
print ( " the sub total is ", sub_total )
print ("percentage-of_sub-total is", percentage_of_sub_total)
print (" the final-total is", final_total)
# Out:
#  the sub total is  6
# percentage-of_sub-total is 0
#  the final-total is 6

# %%
name = input(" enter your first name")
last_name  = input (" enter your last name")
age = input ("enter your age")
favourite_hobby = "reading"
print (" your favourite hobby is", favourite_hobby )
print (" the name is ", name, "and", "last_name is ", last_name , "and", "age is ", age)
# Out:
#  your favourite hobby is reading
#  the name is  Aminu and last_name is  Muhammad and age is  25

# %%
# Additional exercise, 
# Convert miles to kilometers
#Calculate your age in days
#Create a simple tip calculator
#Build a story that uses user input to fill in the blanks
mile = float(input (" ennter the num1 "))
kilometer = float(input (" enter the num2 "))
the_answer_in_kilometer = (float(mile/kilometer))
print (" the_answer_in_kilometer is ", the_answer_in_kilometer )
# Out:
#  the_answer_in_kilometer is  1.0

# %%
# calculate age in days
ages = int(input (" enter your age: "))
weeks = int(input(" enter your weeks: "))
Days = ages*weeks
print = (" the Days is", Days)

# %%
# calculating the age but sir why at line 11 it does not work
ages = 25
weeks = 175
Days = ages*weeks
print (" the Days is", Days)
# Out:
#  the Days is 4375

# %%
# forming a calculator of linears eqns
a = 2
b = 3
x = 2
y = int(a+b*x)
print (" the y is ", y)
# Out:
#  the y is  8

# %%
# building a story to fill in blank
name = input (" enter your name ")
colour = input (" enter your complexion ")
Height = input (" enter your lenth ")
character = input (" enter your habit ")
hobby = (" enter your wish ")
favourite = (" enter your food ")
print (" your namae is ", name, colour ,  Height, character, hobby, favourite ) # how can print them in one single line
print (" the colour is ", colour )
print (" your Height is", Height)
print (" your character is ", character)
print (" your hobby is ", hobby ) # pls why this one is giving me the same input
print (" your favourite is ", favourite )
# Out:
#  your namae is  Aminu white 30m humble  enter your wish   enter your food
#  the colour is  white
#  your Height is 30m
#  your character is  humble
#  your hobby is   enter your wish
#  your favourite is   enter your food

# %%
## 📝 Review and Self-Assessment

### What We Covered:

#✅ Using the `print()` function to display output  
##✅ Getting user input with `input()`  
##✅ Understanding and fixing syntax errors  

### Reflection Questions:

###*Write your responses in the cell below:**

# %% [markdown]
# ---
#
# ## 📝 Review and Self-Assessment
#
# ### What We Covered:
#
# ✅ Using the `print()` function to display output
# ✅ Creating and using variables
# ✅ Getting user input with `input()`
# ✅ Converting strings to numbers with `int()` and `float()`
# ✅ Performing basic calculations
# ✅ Understanding and fixing syntax errors
#
# ### Reflection Questions:
#
# Before our next class, think about:
#
# 1. What part of Python programming was most interesting to you?
# 2. Which concept would you like to practice more?
# 3. What questions do you have about Python so far?
#
# **Write your responses in the cell below:**
# **Your Reflection:**
#
# 1. Most interesting part: [ input function]
#
# 2. Need more practice with: [ ]
#
# 3. My questions: [ my question is how can i plot a map using spacial analysis to detect a location of source, concentration, and disperse area with a particulate matter (pm 2.5ug/m^3) using a given url/ dta type in excel/netcdf file
#
# thank you sir i really appreciate the lesson and most importantly the last advice (practice make perfect)]
